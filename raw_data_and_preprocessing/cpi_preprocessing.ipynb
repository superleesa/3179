# %% [markdown]
# # CPI Data Preprocessing

# %%
import pandas as pd

# %%
df = pd.read_csv("cpi_raw.csv")

# %%
df = df[(df["Unit"] == "Index") & (df["Measure"] == "Index")]
df = df.loc[df["Country"] != "Japan"]

# %%
df = df[["Country", "Subject", "Time", "Value"]]
df.columns = ["Country", "Subject", "Year", "CPI"]

# %%
df
# Out:
#       Country                                            Subject  Year  \
# 8      Russia  CPI: 02 - Alcoholic beverages, tobacco and nar...  2015
# 9      Russia  CPI: 02 - Alcoholic beverages, tobacco and nar...  2016
# 10     Russia  CPI: 02 - Alcoholic beverages, tobacco and nar...  2017
# 11     Russia  CPI: 02 - Alcoholic beverages, tobacco and nar...  2018
# 12     Russia  CPI: 02 - Alcoholic beverages, tobacco and nar...  2019
# ...       ...                                                ...   ...
# 17445  Brazil                   CPI: 11 - Restaurants and hotels  2018
# 17446  Brazil         CPI: 12 - Miscellaneous goods and services  2015
# 17447  Brazil         CPI: 12 - Miscellaneous goods and services  2016
# 17448  Brazil         CPI: 12 - Miscellaneous goods and services  2017
# 17449  Brazil         CPI: 12 - Miscellaneous goods and services  2018
#
#             CPI
# 8      100.0000
# 9      109.8833
# 10     116.4829
# 11     120.2928
# 12     124.4366
# ...         ...
# 17445  117.2591
# 17446  100.0000
# 17447  107.7300
# 17448  111.9912
# 17449  116.8015
#
# [4261 rows x 4 columns]

# %%
selected_countries = ["Germany", "United States", "United Kingdom", "France", "Italy", "Canada"]
df_g7_except_japan = df[df["Country"].isin(selected_countries)]

# %%
df_g7_except_japan
# Out:
#              Country                                            Subject  Year  \
# 15     United States  CPI: 04 - Housing, water, electricity, gas and...  2015
# 16     United States  CPI: 04 - Housing, water, electricity, gas and...  2016
# 17     United States  CPI: 04 - Housing, water, electricity, gas and...  2017
# 18     United States  CPI: 04 - Housing, water, electricity, gas and...  2018
# 19     United States  CPI: 04 - Housing, water, electricity, gas and...  2019
# ...              ...                                                ...   ...
# 17401         Canada         CPI: 12 - Miscellaneous goods and services  2018
# 17402         Canada         CPI: 12 - Miscellaneous goods and services  2019
# 17403         Canada         CPI: 12 - Miscellaneous goods and services  2020
# 17404         Canada         CPI: 12 - Miscellaneous goods and services  2021
# 17405         Canada         CPI: 12 - Miscellaneous goods and services  2022
#
#             CPI
# 15     100.0000
# 16     102.8473
# 17     106.4029
# 18     109.7682
# 19     113.1062
# ...         ...
# 17401  105.5621
# 17402  109.3947
# 17403  113.4492
# 17404  116.3457
# 17405  122.1232
#
# [624 rows x 4 columns]

# %% [markdown]
# ## Preprocessing Japan's CPI data

# %% [markdown]
# Note: Japan follows a new classification method to calculate CPI (called COICOP 18), hence require some preprocessing to ensure that it matches with the old formats that other countries use.

# %%
df2 = pd.read_csv("PRICES_CPI_15102023095505068.csv")

# %%
df2 = df2[(df2["Frequency"] == "Annual")  & (df2["Country"] == "Japan") ]

# %%
df2 = df2[["Country", "Subject", "Measure", "Time", "Value"]]

# %%
df2[df2["Measure"] == "Index"]
# Out:
#     Country                                            Subject Measure  Time  \
# 16    Japan                          CPI (COICOP 18): Services   Index  2015
# 17    Japan                          CPI (COICOP 18): Services   Index  2016
# 18    Japan                          CPI (COICOP 18): Services   Index  2017
# 19    Japan                          CPI (COICOP 18): Services   Index  2018
# 20    Japan                          CPI (COICOP 18): Services   Index  2019
# 21    Japan                          CPI (COICOP 18): Services   Index  2020
# 22    Japan                          CPI (COICOP 18): Services   Index  2021
# 23    Japan                          CPI (COICOP 18): Services   Index  2022
# 32    Japan                 CPI (COICOP 18): 01-12 - All items   Index  2015
# 33    Japan                 CPI (COICOP 18): 01-12 - All items   Index  2016
# 34    Japan                 CPI (COICOP 18): 01-12 - All items   Index  2017
# 35    Japan                 CPI (COICOP 18): 01-12 - All items   Index  2018
# 36    Japan                 CPI (COICOP 18): 01-12 - All items   Index  2019
# 37    Japan                 CPI (COICOP 18): 01-12 - All items   Index  2020
# 38    Japan                 CPI (COICOP 18): 01-12 - All items   Index  2021
# 39    Japan                 CPI (COICOP 18): 01-12 - All items   Index  2022
# 88    Japan     CPI (COICOP 18): All items non-food non-energy   Index  2015
# 89    Japan     CPI (COICOP 18): All items non-food non-energy   Index  2016
# 90    Japan     CPI (COICOP 18): All items non-food non-energy   Index  2017
# 91    Japan     CPI (COICOP 18): All items non-food non-energy   Index  2018
# 92    Japan     CPI (COICOP 18): All items non-food non-energy   Index  2019
# 93    Japan     CPI (COICOP 18): All items non-food non-energy   Index  2020
# 94    Japan     CPI (COICOP 18): All items non-food non-energy   Index  2021
# 95    Japan     CPI (COICOP 18): All items non-food non-energy   Index  2022
# 96    Japan                             CPI (COICOP 18): Goods   Index  2015
# 97    Japan                             CPI (COICOP 18): Goods   Index  2016
# 98    Japan                             CPI (COICOP 18): Goods   Index  2017
# 99    Japan                             CPI (COICOP 18): Goods   Index  2018
# 100   Japan                             CPI (COICOP 18): Goods   Index  2019
# 101   Japan                             CPI (COICOP 18): Goods   Index  2020
# 102   Japan                             CPI (COICOP 18): Goods   Index  2021
# 103   Japan                             CPI (COICOP 18): Goods   Index  2022
# 104   Japan  CPI (COICOP 18): 01 - Food and non-Alcoholic b...   Index  2015
# 105   Japan  CPI (COICOP 18): 01 - Food and non-Alcoholic b...   Index  2016
# 106   Japan  CPI (COICOP 18): 01 - Food and non-Alcoholic b...   Index  2017
# 107   Japan  CPI (COICOP 18): 01 - Food and non-Alcoholic b...   Index  2018
# 108   Japan  CPI (COICOP 18): 01 - Food and non-Alcoholic b...   Index  2019
# 109   Japan  CPI (COICOP 18): 01 - Food and non-Alcoholic b...   Index  2020
# 110   Japan  CPI (COICOP 18): 01 - Food and non-Alcoholic b...   Index  2021
# 111   Japan  CPI (COICOP 18): 01 - Food and non-Alcoholic b...   Index  2022
# 144   Japan                            CPI (COICOP 18): Energy   Index  2015
# 145   Japan                            CPI (COICOP 18): Energy   Index  2016
# 146   Japan                            CPI (COICOP 18): Energy   Index  2017
# 147   Japan                            CPI (COICOP 18): Energy   Index  2018
# 148   Japan                            CPI (COICOP 18): Energy   Index  2019
# 149   Japan                            CPI (COICOP 18): Energy   Index  2020
# 150   Japan                            CPI (COICOP 18): Energy   Index  2021
# 151   Japan                            CPI (COICOP 18): Energy   Index  2022
#
#          Value
# 16   100.00000
# 17   100.30950
# 18   100.32620
# 19   100.59380
# 20   100.87820
# 21   100.37640
# 22    99.09669
# 23    98.56976
# 32   100.00000
# 33    99.87274
# 34   100.35630
# 35   101.34890
# 36   101.82400
# 37   101.79860
# 38   101.56100
# 39   104.09770
# 88   100.00000
# 89   100.37910
# 90   100.35380
# 91   100.55600
# 92   101.00250
# 93   101.11200
# 94   100.37070
# 95   100.69080
# 96   100.00000
# 97    99.44923
# 98   100.38730
# 99   102.11700
# 100  102.78830
# 101  103.27880
# 102  104.04480
# 103  109.73320
# 104  100.00000
# 105  102.01000
# 106  102.67120
# 107  104.31980
# 108  104.55790
# 109  105.80980
# 110  105.75690
# 111  110.94070
# 144  100.00000
# 145   89.77988
# 146   94.56673
# 147  101.15380
# 148  102.51210
# 149   98.18346
# 150  102.07020
# 151  119.47470

# %%
df2[df2["Measure"] == "Index"]["Subject"].unique()
# Out:
# array(['CPI (COICOP 18): Services', 'CPI (COICOP 18): 01-12 - All items',
#        'CPI (COICOP 18): All items non-food non-energy',
#        'CPI (COICOP 18): Goods',
#        'CPI (COICOP 18): 01 - Food and non-Alcoholic beverages',
#        'CPI (COICOP 18): Energy'], dtype=object)

# %% [markdown]
# - can use all items, and 01

# %%
useful_vals = ["CPI (COICOP 18): 01-12 - All items", "CPI (COICOP 18): 01 - Food and non-Alcoholic beverages"]
df_all_and_food = df2[(df2["Measure"] == "Index") & (df2["Subject"].isin(useful_vals))]

# %%
df_others = df2[(df2["Measure"] == "National Index") & (~df2["Subject"].isin(useful_vals))]

# %%
df_japan = pd.concat([df_others, df_all_and_food], axis=0)

# %%
df_japan
# Out:
#     Country                                            Subject  \
# 0     Japan  CPI (COICOP 18): 05 - Furnishings, household e...
# 1     Japan  CPI (COICOP 18): 05 - Furnishings, household e...
# 2     Japan  CPI (COICOP 18): 05 - Furnishings, household e...
# 3     Japan  CPI (COICOP 18): 05 - Furnishings, household e...
# 4     Japan  CPI (COICOP 18): 05 - Furnishings, household e...
# ..      ...                                                ...
# 107   Japan  CPI (COICOP 18): 01 - Food and non-Alcoholic b...
# 108   Japan  CPI (COICOP 18): 01 - Food and non-Alcoholic b...
# 109   Japan  CPI (COICOP 18): 01 - Food and non-Alcoholic b...
# 110   Japan  CPI (COICOP 18): 01 - Food and non-Alcoholic b...
# 111   Japan  CPI (COICOP 18): 01 - Food and non-Alcoholic b...
#
#             Measure  Time      Value
# 0    National Index  2015   97.88333
# 1    National Index  2016   97.50833
# 2    National Index  2017   97.12500
# 3    National Index  2018   96.09167
# 4    National Index  2019   97.89167
# ..              ...   ...        ...
# 107           Index  2018  104.31980
# 108           Index  2019  104.55790
# 109           Index  2020  105.80980
# 110           Index  2021  105.75690
# 111           Index  2022  110.94070
#
# [144 rows x 5 columns]

# %%
df_japan = df_japan[["Country", "Subject", "Time", "Value"]]

# %% [markdown]
# ## Concat the two dataframes

# %%
sorted(df_g7_except_japan["Subject"].unique())
# Out:
# ['CPI: 01 - Food and non-Alcoholic beverages',
#  'CPI: 01-12 - All items',
#  'CPI: 02 - Alcoholic beverages, tobacco and narcotics',
#  'CPI: 03 - Clothing and footwear',
#  'CPI: 04 - Housing, water, electricity, gas and other fuels',
#  'CPI: 05 - Furnishings, household equipment and routine household maintenance',
#  'CPI: 06 - Health',
#  'CPI: 07 - Transport',
#  'CPI: 08 - Communication',
#  'CPI: 09 - Recreation and culture',
#  'CPI: 10 - Education',
#  'CPI: 11 - Restaurants and hotels',
#  'CPI: 12 - Miscellaneous goods and services']

# %%
sorted(df_japan["Subject"].unique())
# Out:
# ['CPI (COICOP 18): 01 - Food and non-Alcoholic beverages',
#  'CPI (COICOP 18): 01-12 - All items',
#  'CPI (COICOP 18): 02 - Alcoholic beverages, tobacco and narcotics',
#  'CPI (COICOP 18): 03 - Clothing and footwear',
#  'CPI (COICOP 18): 04 - Housing, water, electricity, gas and other fuels',
#  'CPI (COICOP 18): 05 - Furnishings, household equipment and routine household maintenance',
#  'CPI (COICOP 18): 06 - Health',
#  'CPI (COICOP 18): 07 - Transport',
#  'CPI (COICOP 18): 08 - Information and communication',
#  'CPI (COICOP 18): 09 - Recreation, sport and culture',
#  'CPI (COICOP 18): 10 - Education services',
#  'CPI (COICOP 18): 11 - Restaurants and accommodation services',
#  'CPI (COICOP 18): 12 - Insurance and financial services',
#  'CPI (COICOP 18): 13 - Personal care, social protection and miscellaneous goods and services',
#  'CPI (COICOP 18): Goods',
#  'CPI (COICOP 18): Housing',
#  'CPI (COICOP 18): Services',
#  'CPI (COICOP 18): Services less housing']

# %% [markdown]
# Here, I'll ensure that CPI 13 from 2018 match CPI 12 of 1999.(but this is technically inaccurate)

# %%
new_to_old = {new:old for new, old in zip(sorted(df_japan["Subject"].unique()), sorted(df_g7_except_japan["Subject"].unique()))}

# %%
new_to_old.pop("CPI (COICOP 18): 12 - Insurance and financial services")
# Out:
# 'CPI: 12 - Miscellaneous goods and services'

# %%
new_to_old["CPI (COICOP 18): 13 - Personal care, social protection and miscellaneous goods and services"] = "CPI: 12 - Miscellaneous goods and services"

# %%
df_japan["Subject"] = df_japan["Subject"].replace(new_to_old)
# Out:
# C:\Users\super\AppData\Local\Temp\ipykernel_26336\3716251735.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_japan["Subject"] = df_japan["Subject"].replace(new_to_old)

# %%
df_japan["Subject"].unique()
# Out:
# array(['CPI: 05 - Furnishings, household equipment and routine household maintenance',
#        'CPI: 08 - Communication', 'CPI: 11 - Restaurants and hotels',
#        'CPI: 02 - Alcoholic beverages, tobacco and narcotics',
#        'CPI (COICOP 18): Goods', 'CPI: 10 - Education',
#        'CPI: 12 - Miscellaneous goods and services',
#        'CPI: 04 - Housing, water, electricity, gas and other fuels',
#        'CPI (COICOP 18): Services less housing',
#        'CPI: 03 - Clothing and footwear', 'CPI (COICOP 18): Housing',
#        'CPI: 07 - Transport', 'CPI (COICOP 18): Services',
#        'CPI: 06 - Health', 'CPI: 09 - Recreation and culture',
#        'CPI (COICOP 18): 12 - Insurance and financial services',
#        'CPI: 01-12 - All items',
#        'CPI: 01 - Food and non-Alcoholic beverages'], dtype=object)

# %%
# remove any classification that is not present in the old system

df_japan = df_japan[df_japan["Subject"].isin(df_g7_except_japan["Subject"].unique())]

# %%
df_japan["Subject"].unique()
# Out:
# array(['CPI: 05 - Furnishings, household equipment and routine household maintenance',
#        'CPI: 08 - Communication', 'CPI: 11 - Restaurants and hotels',
#        'CPI: 02 - Alcoholic beverages, tobacco and narcotics',
#        'CPI: 10 - Education',
#        'CPI: 12 - Miscellaneous goods and services',
#        'CPI: 04 - Housing, water, electricity, gas and other fuels',
#        'CPI: 03 - Clothing and footwear', 'CPI: 07 - Transport',
#        'CPI: 06 - Health', 'CPI: 09 - Recreation and culture',
#        'CPI: 01-12 - All items',
#        'CPI: 01 - Food and non-Alcoholic beverages'], dtype=object)

# %% [markdown]
# Check that both of these dataframes have the same subjects.

# %%
sorted(df_japan["Subject"].unique()) == sorted(df_g7_except_japan["Subject"].unique())
# Out:
# True

# %% [markdown]
# Ensure that both dataframes have the same column names

# %%
df_japan.columns
# Out:
# Index(['Country', 'Subject', 'Time', 'Value'], dtype='object')

# %%
df_g7_except_japan.columns
# Out:
# Index(['Country', 'Subject', 'Year', 'CPI'], dtype='object')

# %%
df_japan.columns = df_g7_except_japan.columns

# %%
df_g7 = pd.concat([df_japan, df_g7_except_japan], axis=0)

# %%
df_g7.to_csv("cpi_g7.csv", index=False)

# %%
import matplotlib.pyplot as plt
