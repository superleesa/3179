# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("raw_avg_wage.csv")

# %%
df
# Out:
#     COUNTRY     Country SERIES                 Series  TIME  Time Unit Code  \
# 0       AUS   Australia  CPNCU  Current prices in NCU  2000  2000       AUD
# 1       AUS   Australia  CPNCU  Current prices in NCU  2001  2001       AUD
# 2       AUS   Australia  CPNCU  Current prices in NCU  2002  2002       AUD
# 3       AUS   Australia  CPNCU  Current prices in NCU  2003  2003       AUD
# 4       AUS   Australia  CPNCU  Current prices in NCU  2004  2004       AUD
# ..      ...         ...    ...                    ...   ...   ...       ...
# 859     CRI  Costa Rica  CPNCU  Current prices in NCU  2017  2017       NaN
# 860     CRI  Costa Rica  CPNCU  Current prices in NCU  2018  2018       NaN
# 861     CRI  Costa Rica  CPNCU  Current prices in NCU  2019  2019       NaN
# 862     CRI  Costa Rica  CPNCU  Current prices in NCU  2020  2020       NaN
# 863     CRI  Costa Rica  CPNCU  Current prices in NCU  2021  2021       NaN
#
#                   Unit  PowerCode Code PowerCode  Reference Period Code  \
# 0    Australian Dollar               0     Units                    NaN
# 1    Australian Dollar               0     Units                    NaN
# 2    Australian Dollar               0     Units                    NaN
# 3    Australian Dollar               0     Units                    NaN
# 4    Australian Dollar               0     Units                    NaN
# ..                 ...             ...       ...                    ...
# 859                NaN               0     Units                    NaN
# 860                NaN               0     Units                    NaN
# 861                NaN               0     Units                    NaN
# 862                NaN               0     Units                    NaN
# 863                NaN               0     Units                    NaN
#
#      Reference Period         Value  Flag Codes  Flags
# 0                 NaN  4.624687e+04         NaN    NaN
# 1                 NaN  4.831598e+04         NaN    NaN
# 2                 NaN  5.005276e+04         NaN    NaN
# 3                 NaN  5.179859e+04         NaN    NaN
# 4                 NaN  5.419940e+04         NaN    NaN
# ..                ...           ...         ...    ...
# 859               NaN  8.891675e+06         NaN    NaN
# 860               NaN  9.347486e+06         NaN    NaN
# 861               NaN  9.846887e+06         NaN    NaN
# 862               NaN  1.089482e+07         NaN    NaN
# 863               NaN  1.108573e+07         NaN    NaN
#
# [864 rows x 15 columns]

# %%
all(df[["Country", "Time", "Value"]].groupby(["Country", "Time"]).size() == 1)
# Out:
# True

# %%
df_oup = df[["Country", "Time", "Value"]]

# %%
df_oup.to_csv("avg_wage.csv", index=False)

# %%
countries = df_oup.groupby("Country")
for country_name, country_df in countries:
    plt.plot(country_df["Time"], country_df["Value"], label=country_name, color="red" if country_name == "Japan" else "grey")
